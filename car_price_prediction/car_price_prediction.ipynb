# %%
#importing the necessary libraries
import pandas as pd 
import numpy as np
import seaborn as sn

# %%
#getting the data 
data = 'https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv'

# %%
# !wget $data

# %%
df = pd.read_csv('data.csv')

# %%
df.head()

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
strings = list(df.dtypes[df.dtypes == 'str'].index)
strings

# %%
for col in strings:
    df[col] = df[col].str.lower().str.replace(' ', '_')

# %%
df.dtypes

# %% [markdown]
# # EXPLORATORY DATA ANALYLIS

# %%
#find the number of unique values in each column
for col in df.columns:
    print(col)
    print(df[col].unique()[:5])
    print(df[col].nunique())
    print()

# %% [markdown]
# ### Distribution of the price (target variable)

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
sn.histplot(df.msrp, bins=50)

# %%
sn.histplot(df.msrp[df.msrp < 100000],bins=50)

# %%
price_logs = np.log1p(df.msrp)

# %%
sn.histplot(price_logs, bins=50)

# %%
#check for missing values
df.isnull().sum()

# %% [markdown]
# ### Setting up validation framework

# %%
n = len(df)
n_val = int(n * 0.2)
n_test = int(n * 0.2)
n_train = n - n_val - n_test

# %%
n_train, n_val, n_test

# %%
idx = np.arange(n)

# %%
np.random.seed(2)
np.random.shuffle(idx)
idx

# %%
df_train = df.iloc[idx[:n_train]]
df_val = df.iloc[idx[n_train:n_train + n_val]]
df_test = df.iloc[idx[n_train + n_val:]]

# %%
df_train.head()

# %%
y_train = np.log1p(df_train.msrp)
y_test = np.log1p(df_test.msrp)
y_val = np.log1p(df_test.msrp)

# %%
len(y_train)

# %% [markdown]
# ## Linear regression

# %%
df_train.iloc[10]

# %%
X = [
     [148, 24, 1385],
    [132, 25, 2031],
    [453, 11, 86],
    [158, 24, 185],
    [172, 25, 201],
    [413, 11, 86],
    [38,  54, 185],
    [142, 25, 431],
    [478, 31, 80]
 ]

X = np.array(X)
X

# %%
ones = np.ones(X.shape[0])
ones

# %%
X_full = np.column_stack([ones, X])
X_full

# %%
y = [10000, 20000, 15000, 20050, 10000, 20000, 15000, 25000, 12000]

# %%
XTX = X_full.T.dot(X_full)
XTX_inv = np.linalg.inv(XTX)
w_full = XTX_inv.dot(X_full.T).dot(y)

# %%
w0 = w_full[0]
w = w_full[1:]

# %%
def train_linear_regression(X,y):
    ones = np.ones(X.shape[0]) #create an array of ones
    X = np.column_stack([ones,X]) #add a column of ones

    XTX = X.T.dot(X) 
    XTX_inv = np.linalg.inv(XTX)
    w_full = XTX_inv.dot(X.T).dot(y)
    return w_full[0], w_full[1:]

# %%
train_linear_regression(X,y)
