# %%
#importing the necessary libraries
import pandas as pd 
import numpy as np
import seaborn as sn

# %%
#getting the data 
#data = 'https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv'

# %%
#!wget $data

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
strings = list(df.dtypes[df.dtypes == 'str'].index)
strings
# Out:
# ['make',
#  'model',
#  'engine_fuel_type',
#  'transmission_type',
#  'driven_wheels',
#  'market_category',
#  'vehicle_size',
#  'vehicle_style']

# %%
for col in strings:
    df[col] = df[col].str.lower().str.replace(' ', '_')

# %%
df.dtypes
# Out:
# make                     str
# model                    str
# year                   int64
# engine_fuel_type         str
# engine_hp            float64
# engine_cylinders     float64
# transmission_type        str
# driven_wheels            str
# number_of_doors      float64
# market_category          str
# vehicle_size             str
# vehicle_style            str
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# msrp                   int64
# dtype: object

# %% [markdown]
# # EXPLORATORY DATA ANALYLIS

# %%
#find the number of unique values in each column
for col in df.columns:
    print(col)
    print(df[col].unique()[:5])
    print(df[col].nunique())
    print()
# Out:
# make
# <StringArray>
# ['bmw', 'audi', 'fiat', 'mercedes-benz', 'chrysler']
# Length: 5, dtype: str
# 48
#
# model
# <StringArray>
# ['1_series_m', '1_series', '100', '124_spider', '190-class']
# Length: 5, dtype: str
# 914
#
# year
# [2011 2012 2013 1992 1993]
# 28
#
# engine_fuel_type
# <StringArray>
# [   'premium_unleaded_(required)',               'regular_unleaded',
#  'premium_unleaded_(recommended)',       'flex-fuel_(unleaded/e85)',
#                          'diesel']
# Length: 5, dtype: str
# 10
#
# engine_hp
# [335. 300. 230. 320. 172.]
# 356
#
# engine_cylinders
# [ 6.  4.  5.  8. 12.]
# 9
#
# transmission_type
# <StringArray>
# ['manual', 'automatic', 'automated_manual', 'direct_drive', 'unknown']
# Length: 5, dtype: str
# 5
#
# driven_wheels
# <StringArray>
# ['rear_wheel_drive', 'front_wheel_drive', 'all_wheel_drive',
#  'four_wheel_drive']
# Length: 4, dtype: str
# 4
#
# number_of_doors
# [ 2.  4.  3. nan]
# 3
#
# market_category
# <StringArray>
# ...

# %% [markdown]
# ### Distribution of the price (target variable)

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
sn.histplot(df.msrp, bins=50)
# Out:
# <Axes: xlabel='msrp', ylabel='Count'>

# %%
sn.histplot(df.msrp[df.msrp < 100000],bins=50)
# Out:
# <Axes: xlabel='msrp', ylabel='Count'>

# %%
price_logs = np.log1p(df.msrp)

# %%
sn.histplot(price_logs, bins=50)
# Out:
# <Axes: xlabel='msrp', ylabel='Count'>

# %%
#check for missing values
df.isnull().sum()
# Out:
# make                    0
# model                   0
# year                    0
# engine_fuel_type        3
# engine_hp              69
# engine_cylinders       30
# transmission_type       0
# driven_wheels           0
# number_of_doors         6
# market_category      3742
# vehicle_size            0
# vehicle_style           0
# highway_mpg             0
# city_mpg                0
# popularity              0
# msrp                    0
# dtype: int64

# %% [markdown]
# ### Setting up validation framework

# %%
n = len(df)
n_val = int(n * 0.2)
n_test = int(n * 0.2)
n_train = n - n_val - n_test

# %%
n_train, n_val, n_test
# Out:
# (7150, 2382, 2382)

# %%
idx = np.arange(n)

# %%
np.random.seed(2)
np.random.shuffle(idx)
idx
# Out:
# array([2735, 6720, 5878, ..., 6637, 2575, 7336], shape=(11914,))

# %%
df_train = df.iloc[idx[:n_train]]
df_val = df.iloc[idx[n_train:n_train + n_val]]
df_test = df.iloc[idx[n_train + n_val:]]

# %%
df_train.head()
# Out:
#              make    model  year          engine_fuel_type  engine_hp  \
# 2735    chevrolet   cobalt  2008          regular_unleaded      148.0
# 6720       toyota   matrix  2012          regular_unleaded      132.0
# 5878       subaru  impreza  2016          regular_unleaded      148.0
# 11190  volkswagen  vanagon  1991          regular_unleaded       90.0
# 4554         ford    f-150  2017  flex-fuel_(unleaded/e85)      385.0
#
#        engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 2735                4.0            manual  front_wheel_drive              2.0
# 6720                4.0         automatic  front_wheel_drive              4.0
# 5878                4.0         automatic    all_wheel_drive              4.0
# 11190               4.0            manual   rear_wheel_drive              3.0
# 4554                8.0         automatic   four_wheel_drive              4.0
#
# ...

# %%
y_train = np.log1p(df_train.msrp.values)
y_test = np.log1p(df_test.msrp.values)
y_val = np.log1p(df_val.msrp.values)

# %%
# Out:
# np.float64(35000.00000000001)

# %% [markdown]
# ## Linear regression

# %%
df_train.iloc[10]
# Out:
# make                                 rolls-royce
# model                     phantom_drophead_coupe
# year                                        2015
# engine_fuel_type     premium_unleaded_(required)
# engine_hp                                  453.0
# engine_cylinders                            12.0
# transmission_type                      automatic
# driven_wheels                   rear_wheel_drive
# number_of_doors                              2.0
# market_category        exotic,luxury,performance
# vehicle_size                               large
# vehicle_style                        convertible
# highway_mpg                                   19
# city_mpg                                      11
# popularity                                    86
# msrp                                      479775
# Name: 7557, dtype: object

# %%
X = [
     [148, 24, 1385],
    [132, 25, 2031],
    [453, 11, 86],
    [158, 24, 185],
    [172, 25, 201],
    [413, 11, 86],
    [38,  54, 185],
    [142, 25, 431],
    [478, 31, 80]
 ]

X = np.array(X)
X
# Out:
# array([[ 148,   24, 1385],
#        [ 132,   25, 2031],
#        [ 453,   11,   86],
#        [ 158,   24,  185],
#        [ 172,   25,  201],
#        [ 413,   11,   86],
#        [  38,   54,  185],
#        [ 142,   25,  431],
#        [ 478,   31,   80]])

# %%
ones = np.ones(X.shape[0])
ones
# Out:
# array([1., 1., 1., 1., 1., 1., 1., 1., 1.])

# %%
X_full = np.column_stack([ones, X])
X_full
# Out:
# array([[1.000e+00, 1.480e+02, 2.400e+01, 1.385e+03],
#        [1.000e+00, 1.320e+02, 2.500e+01, 2.031e+03],
#        [1.000e+00, 4.530e+02, 1.100e+01, 8.600e+01],
#        [1.000e+00, 1.580e+02, 2.400e+01, 1.850e+02],
#        [1.000e+00, 1.720e+02, 2.500e+01, 2.010e+02],
#        [1.000e+00, 4.130e+02, 1.100e+01, 8.600e+01],
#        [1.000e+00, 3.800e+01, 5.400e+01, 1.850e+02],
#        [1.000e+00, 1.420e+02, 2.500e+01, 4.310e+02],
#        [1.000e+00, 4.780e+02, 3.100e+01, 8.000e+01]])

# %%
y = [10000, 20000, 15000, 20050, 10000, 20000, 15000, 25000, 12000]

# %%
XTX = X_full.T.dot(X_full)
XTX_inv = np.linalg.inv(XTX)
w_full = XTX_inv.dot(X_full.T).dot(y)

# %%
w0 = w_full[0]
w = w_full[1:]

# %%
def train_linear_regression(X,y):
    ones = np.ones(X.shape[0]) #create an array of ones
    X = np.column_stack([ones,X]) #add a column of ones

    XTX = X.T.dot(X) 
    XTX_inv = np.linalg.inv(XTX)
    w_full = XTX_inv.dot(X.T).dot(y)
    return w_full[0], w_full[1:]

# %%
train_linear_regression(X,y)
# Out:
# (np.float64(25446.276250638708),
#  array([ -15.21872486, -191.13273515,   -1.18398251]))

# %% [markdown]
# # Car baseline model

# %%
df_train.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='str')

# %%
base = ['engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg', 'popularity']

X_train = df_train[base].fillna(0).values #replace nullvalues with 0
w0, w = train_linear_regression(X_train, y_train)

# %%
y_pred = w0 + X_train.dot(w)

# %%
sn.histplot(y_pred, color='red', alpha=0.5, bins=50)
sn.histplot(y_train, color='blue', alpha=0.5, bins=50)
# Out:
# <Axes: xlabel='msrp', ylabel='Count'>

# %% [markdown]
# # RMSE

# %%
def rmse(y, y_pred):
    se = (y - y_pred) ** 2
    mse = se.mean()
    return np.sqrt(mse)

# %%
rmse(y_train,y_pred)
# Out:
# np.float64(0.7554192603920132)

# %% [markdown]
# # Model validation

# %%
#handles nulls and returns an array
def prepare_X(df):
    df_num = df[base]
    df_num = df_num.fillna(0)
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)
X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
rmse(y_val, y_pred)
# Out:
# np.float64(1.3847971817298534)

# %% [markdown]
# # Feature Engineering

# %%
def prepare_X(df):
    df = df.copy()
    
    df['age'] = 2017 - df['year']
    features = base + ['age']
    
    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)

X_val = prepare_X(df_val)
y_pred = w0 + X_train.dot(w)
rmse(y_train, y_pred)
# Out:
# np.float64(0.5175055465840046)

# %%
X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
rmse(y_val, y_pred)
# Out:
# np.float64(1.4684788816476781)

# %%
sn.histplot(y_pred, color='red', alpha=0.5, bins=50)
sn.histplot(y_val, color='blue', alpha=0.5, bins=50)
# Out:
# <Axes: xlabel='msrp', ylabel='Count'>

# %% [markdown]
# # Categorical variables

# %%
def prepare_X(df):
    df = df.copy()
    
    df['age'] = 2017 - df['year']
    features = base + ['age']

    for v in [2,3,4]:
        df['num_of_doors_%s' % v] = (df.number_of_doors == v).astype(int)
        features.append('num_of_doors_%s' % v)
    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
rmse(y_val, y_pred)
# Out:
# np.float64(1.4691134866916367)

# %%
categorical_columns = list(df_train.dtypes[df_train.dtypes == 'str'].index)
categorical = {}

for c in categorical_columns:
    categorical[c] = list(df_train[c].value_counts().head().index)
categorical
# Out:
# {'make': ['chevrolet', 'ford', 'volkswagen', 'toyota', 'dodge'],
#  'model': ['silverado_1500', 'tundra', 'f-150', 'sierra_1500', 'tacoma'],
#  'engine_fuel_type': ['regular_unleaded',
#   'premium_unleaded_(required)',
#   'premium_unleaded_(recommended)',
#   'flex-fuel_(unleaded/e85)',
#   'diesel'],
#  'transmission_type': ['automatic',
#   'manual',
#   'automated_manual',
#   'direct_drive',
#   'unknown'],
#  'driven_wheels': ['front_wheel_drive',
#   'rear_wheel_drive',
#   'all_wheel_drive',
#   'four_wheel_drive'],
#  'market_category': ['crossover',
#   'flex_fuel',
#   'luxury',
#   'hatchback',
#   'luxury,performance'],
#  'vehicle_size': ['compact', 'midsize', 'large'],
#  'vehicle_style': ['sedan',
#   '4dr_suv',
#   'coupe',
#   'convertible',
#   '4dr_hatchback']}

# %%
def prepare_X(df):
    df = df.copy()
    
    df['age'] = 2017 - df['year']
    features = base + ['age']

    for v in [2,3,4]:
        df['num_of_doors_%s' % v] = (df.number_of_doors == v).astype(int)
        features.append('num_of_doors_%s' % v)
   
    for name, values in categorical.items():
        for value in values:
            df['%s_%s' % (name,value)] = (df[name] == value).astype(int)
            features.append('%s_%s' % (name,value))
    
    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
rmse(y_val, y_pred)
# Out:
# np.float64(136.45792487690292)

# %% [markdown]
# # Regularization

# %%
def train_linear_regression(X,y, r=0.001):
    ones = np.ones(X.shape[0]) #create an array of ones
    X = np.column_stack([ones,X]) #add a column of ones
    
    XTX = X.T.dot(X) 
    XTX = XTX + r * np.eye(XTX.shape[0]) #regularization
    
    XTX_inv = np.linalg.inv(XTX)
    w_full = XTX_inv.dot(X.T).dot(y)
    return w_full[0], w_full[1:]

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train, r=0.001)

X_train = prepare_X(df_train)
y_pred = w0 + X_train.dot(w)
rmse(y_train, y_pred)
# Out:
# np.float64(0.4543064266090477)

# %%
X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
rmse(y_val, y_pred)
# Out:
# np.float64(0.4516923037899266)

# %% [markdown]
# # Model Tuning

# %%
df_full_train = pd.concat([df_train, df_val]).reset_index(drop=True)
y_full_train = np.concatenate([y_train,y_val])

# %%
df_full_train.head()
# Out:
#          make    model  year          engine_fuel_type  engine_hp  \
# 0   chevrolet   cobalt  2008          regular_unleaded      148.0
# 1      toyota   matrix  2012          regular_unleaded      132.0
# 2      subaru  impreza  2016          regular_unleaded      148.0
# 3  volkswagen  vanagon  1991          regular_unleaded       90.0
# 4        ford    f-150  2017  flex-fuel_(unleaded/e85)      385.0
#
#    engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 0               4.0            manual  front_wheel_drive              2.0
# 1               4.0         automatic  front_wheel_drive              4.0
# 2               4.0         automatic    all_wheel_drive              4.0
# 3               4.0            manual   rear_wheel_drive              3.0
# 4               8.0         automatic   four_wheel_drive              4.0
#
#   market_category vehicle_size      vehicle_style  highway_mpg  city_mpg  \
# ...

# %%
X_full_train = prepare_X(df_full_train)
w0, w = train_linear_regression(X_full_train, y_full_train, r=0.001)

# %%
X_test = prepare_X(df_test)
y_pred = w0 + X_test.dot(w)
score = rmse(y_test,y_pred)

# %%
score
# Out:
# np.float64(0.44763897294038413)

# %% [markdown]
# # using the model

# %%
car = df_test.iloc[8].to_dict()

# %%
df_car = pd.DataFrame([car])
df_car
# Out:
#         make     model  year                engine_fuel_type  engine_hp  \
# 0  chevrolet  corvette  2017  premium_unleaded_(recommended)      460.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               8.0            manual  rear_wheel_drive              2.0
#
#     market_category vehicle_size vehicle_style  highway_mpg  city_mpg  \
# 0  high-performance      compact   convertible           25        16
#
#    popularity   msrp
# 0        1385  69450

# %%
X_car = prepare_X(df_car)
y_car = w0 + X_car.dot(w)
y_car = y_car[0]

# %%
np.expm1(y_car)
# Out:
# np.float64(97622.42926590153)

# %%
np.expm1(y_test[8])
# Out:
# np.float64(69449.99999999999)

# %%
sn.histplot(y_pred, color='red', alpha=0.5, bins=50)
# Out:
# 8
